# %%
import pandas as pd
import numpy as np
import statistics
import math
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sbi_data.csv', usecols = ['Date', 'Close'], nrows = 66)

# %%
df
# Out:
#           Date       Close
# 0   2020-07-01  184.800003
# 1   2020-07-02  185.449997
# 2   2020-07-03  184.699997
# 3   2020-07-06  188.050003
# 4   2020-07-07  188.600006
# 5   2020-07-08  191.899994
# 6   2020-07-09  199.100006
# 7   2020-07-10  195.600006
# 8   2020-07-13  192.699997
# 9   2020-07-14  186.050003
# 10  2020-07-15  183.800003
# 11  2020-07-16  186.250000
# 12  2020-07-17  188.199997
# 13  2020-07-20  190.750000
# 14  2020-07-21  194.399994
# 15  2020-07-22  192.000000
# 16  2020-07-23  198.250000
# 17  2020-07-24  191.949997
# 18  2020-07-27  187.149994
# 19  2020-07-28  189.449997
# 20  2020-07-29  191.199997
# 21  2020-07-30  186.550003
# 22  2020-07-31  191.449997
# 23  2020-08-03  192.250000
# 24  2020-08-04  191.600006
# 25  2020-08-05  191.449997
# 26  2020-08-06  190.949997
# 27  2020-08-07  190.649994
# 28  2020-08-10  193.800003
# 29  2020-08-11  195.050003
# ..         ...         ...
# 36  2020-08-20  194.750000
# 37  2020-08-21  198.399994
# 38  2020-08-24  201.449997
# 39  2020-08-25  207.949997
# 40  2020-08-26  209.850006
# 41  2020-08-27  215.649994
# 42  2020-08-28  224.850006
# 43  2020-08-31  212.000000
# 44  2020-09-01  218.100006
# 45  2020-09-02  216.250000
# 46  2020-09-03  213.149994
# 47  2020-09-04  206.600006
# 48  2020-09-07  207.899994
# 49  2020-09-08  204.050003
# 50  2020-09-09  194.850006
# 51  2020-09-10  198.149994
# 52  2020-09-11  202.699997
# 53  2020-09-14  198.500000
# 54  2020-09-15  200.149994
# 55  2020-09-16  198.199997
# 56  2020-09-17  195.449997
# 57  2020-09-18  192.600006
# 58  2020-09-21  185.800003
# 59  2020-09-22  186.199997
# 60  2020-09-23  183.800003
# 61  2020-09-24  176.350006
# 62  2020-09-25  182.199997
# 63  2020-09-28  187.250000
# 64  2020-09-29  185.050003
# 65  2020-09-30  185.399994
#
# [66 rows x 2 columns]

# %%
U = []
for i in range(65):
    U.append( math.log(df.Close[i+1]/df.Close[i]) )
# print(U)

# %%
variance = statistics.variance(U)
sigma = math.sqrt(variance)
print(variance, sigma)
# Out:
# 0.0004964753607186511 0.022281727058705552

# %%
mean = statistics.mean(U)
print(mean)
# Out:
# 4.986838966067723e-05

# %%
mu = variance/2 + mean
print(mu)
# Out:
# 0.0002981060700200028

# %%
S = []

# %%
# t1 -> t(i)
# t2 -> t(i+1)
def predict(t1, t2):
    S[t2] = S[t1] * math.exp( (mu-variance/2)*(t2-t1) + sigma * math.sqrt((t2-t1)) * np.random.normal(0.00, 1.00))
    return S[t2]

# %%
# 7th of October is Day Number 5 (Day 69 in CSV)
# 14th of October is Day Number 10 (Day 74 in CSV)
# 21st of October is Day Number 15 (Day 79 in CSV)
# *** Saturday - Sundays are off***

# %%
data = []
for i in range(100000):
    data.append(0.00)

N = 1000
for ctr in range(N):
    S.clear()
    S.append(df.Close[65])
    
    for i in range(1, 16):
        S.append(S[i-1]*math.exp(mean + np.sqrt(variance)*np.random.normal(0,1,1)))
    
    for j in range(len(S)):
        data[j] += S[j]

while data[-1] == 0.00:
    data.pop()
    
for j in range(len(data)):
    data[j] /= N

print(data)
# Out:
# [185.39999400000417, 185.3929084299545, 185.28757987973512, 185.3490699584361, 185.51802124567615, 185.43769472802248, 185.64409412717578, 185.78637039132232, 185.98689643209894, 186.1016571871719, 186.11738247873322, 186.3452599584471, 186.41431190122435, 186.3097082210408, 186.34705419834552, 186.43475113254613]

# %%
df = pd.read_csv('sbi_data.csv', usecols = ['Date', 'Close'])

# %%
key = []
for i in range(65):
    key.append(df.Close[i])

for i in data:
    key.append(i)
